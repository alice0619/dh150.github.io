# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
columns = ["Prefecture", "VisitRate(%)"]

tokyo = ["Tokyo",45.6182]
osaka = ["Osaka",36.6257]
chiba = ["Chiba",35.6482]
kyoto = ["Kyoto",25.7666]
fukuoka = ["Fukuoka",10.3762]
nara = ["Nara",8.9475]
hokkaido = ["Hokkaido",7.861]
aichi = ["Aichi",7.8444]
kanagawa = ["Kanagawa",7.5163]
okinawa = ["Okinawa",6.7658]

hyogo = ["Hyogo",6.0158]
yamanashi = ["Yamanashi",4.6054]
oita = ["Oita",4.21]
shizuoka = ["Shizuoka",4.1877]
hiroshima = ["Hiroshima",2.8976]
nagano = ["Nagano",2.6799]
gifu = ["Gifu",2.5979]
kumamoto = ["Kumamoto",1.9305]
ishikawa = ["Ishikawa",1.875]
nagasaki = ["Nagasaki",1.7484]

tochigi = ["Tochigi",1.3002]
kagoshima = ["Kagoshima",1.1636]
wakayama = ["Wakayama",1.1437]
saga = ["Saga",1.0811]
toyama = ["Toyama",1.056]
okayama = ["Okayama",1.0009]
saitama = ["Saitama",1.0008]
kagawa = ["Kagawa",0.8875]
miyagi = ["Miyagi",0.8845]
yamaguchi = ["Yamaguchi",0.8603]

ibaraki = ["Ibaraki",0.8089]
shiga = ["Shiga",0.6593]
miyazaki = ["Miyazaki",0.6224]
mie = ["Mie",0.621]
aomori = ["Aomori",0.5954]
gunma = ["Gunma",0.5377]
niigata = ["Niigata",0.5181]
tottori = ["Tottori",0.4054]
ehime = ["Ehime",0.3976]
fukushima = ["Fukushima",0.3382]

iwate = ["Iwate",0.3221]
yamagata = ["Yamagata",0.3047]
akita = ["Akita",0.3028]
tokushima = ["Tokushima",0.2534]
shimane = ["Shimane",0.2467]
kochi = ["Kochi",0.2073]
fukui = ["Fukui",0.1716]

# %%
df = pd.DataFrame([tokyo, osaka, chiba, kyoto, fukuoka, nara, hokkaido, aichi, kanagawa, okinawa, 
                  hyogo, yamanashi, oita, shizuoka, hiroshima, nagano, gifu, kumamoto, ishikawa, nagasaki, 
                  tochigi, kagoshima, wakayama, saga, toyama, okayama, saitama, kagawa, miyagi, yamaguchi, 
                  ibaraki, shiga, miyazaki, mie, aomori, gunma, niigata, tottori, ehime, fukushima, 
                  iwate, yamagata, akita, tokushima, shimane, kochi, fukui], columns=columns)
df
# Out:
#    Prefecture  VisitRate(%)
# 0       Tokyo       45.6182
# 1       Osaka       36.6257
# 2       Chiba       35.6482
# 3       Kyoto       25.7666
# 4     Fukuoka       10.3762
# 5        Nara        8.9475
# 6    Hokkaido        7.8610
# 7       Aichi        7.8444
# 8    Kanagawa        7.5163
# 9     Okinawa        6.7658
# 10      Hyogo        6.0158
# 11  Yamanashi        4.6054
# 12       Oita        4.2100
# 13   Shizuoka        4.1877
# 14  Hiroshima        2.8976
# 15     Nagano        2.6799
# 16       Gifu        2.5979
# 17   Kumamoto        1.9305
# 18   Ishikawa        1.8750
# 19   Nagasaki        1.7484
# 20    Tochigi        1.3002
# 21  Kagoshima        1.1636
# 22   Wakayama        1.1437
# 23       Saga        1.0811
# 24     Toyama        1.0560
# 25    Okayama        1.0009
# 26    Saitama        1.0008
# 27     Kagawa        0.8875
# 28     Miyagi        0.8845
# 29  Yamaguchi        0.8603
# 30    Ibaraki        0.8089
# 31      Shiga        0.6593
# ...

# %%
df.plot.barh(x = "Prefecture", y = "VisitRate(%)", figsize = (12, 9))
